# %% [markdown]
# <center>
# <img src="https://drive.google.com/uc?id=1f1gGVI-rxcHjA90WEGNvvtSXF1pAxQwg" alt="Fasilkom UI" width="300"/>
#
# CSGE603130 • Kecerdasan Artifisial dan Sains Data Dasar
#
# Semester Ganjil 2022/2023
#
# Fakultas Ilmu Komputer, Universitas Indonesia
#
# ## **Lab *2*: *Statistics & Data Visualization***
#
# ### **Tenggat Waktu: 17 September 2022, 23.55 WIB**
# </center>
#
# #### **Ketentuan:**
#
# 1. Dokumen *template* lab dengan format .ipynb dan dataset (jika dibutuhkan) telah disediakan di SCeLe
# 2. Jalankan kode pada dokumen .ipynb dan perhatikan dengan saksama apa yang potongan kode tersebut lakukan beserta dengan keluarannya. Jawablah **pertanyaan yang disisipkan** pada potongan program yang diberikan.
# 3. Dokumen Jupyter Notebook yang telah dilengkapi dengan jawaban dikumpulkan dengan format penamaan **Kelas_Lab2_NPM_Nama.ipynb**. Contoh: A_Lab2_2006123456_Budi.ipynb
# 4. Kumpulkan dokumen tersebut pada submisi yang telah disediakan di SCeLe sesuai dengan kelas masing-masing sebelum **17 September 2022, 23.55 WIB**. Keterlambatan pengumpulan akan dikenakan pinalti.
# 5. Lab ini dirancang sebagai **tugas mandiri**. Plagiarisme tidak diperkenankan dalam bentuk apapun. Adapun kolaborasi berupa diskusi (tanpa menyalin maupun mengambil jawaban orang lain) dan literasi masih diperbolehkan dengan mencantumkan kolaborator dan sumber.

# %% [markdown]
# ## **Pernyataan Integritas**
#
# Wajib diisi. Tanpa pernyataan integritas submisi akan dikenakan pinalti.

# %%
# Isi dengan data diri Anda
NAMA = "Riris Melissa Winona Togatorop"
KELAS = "E"
NPM = "1906398906"

# Isi dengan NPM teman yang berdiskusi dengan Anda
KOLABORATOR = []

# Isi dengan sumber referensi yang Anda gunakan dalam mengerjakan
REFERENSI = ["https://seaborn.pydata.org/generated/seaborn.heatmap.html","https://stackoverflow.com/questions/69026091/how-to-filter-for-a-specific-number-of-rows-in-jupyter-notebook-with-python-3","https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.pie.html","https://thispointer.com/python-pandas-how-to-drop-rows-in-dataframe-by-index-labels/","https://www.kite.com/python/answers/how-to-group-a-pandas-dataframe-by-a-column-and-compute-the-mean-of-each-group-in-python",]

# %%
PERNYATAAN_INTEGRITAS = "Saya, %s dari kelas %s dengan NPM %s, menyatakan bahwa seluruh jawaban pada pekerjaan ini murni saya kerjakan sendiri.\n\
Saya tidak mencontek jawaban, memberikan jawaban, maupun menyalin dari sumber manapun.\n \
\n\
Jika saya melanggar pernyataan tersebut, saya siap menerima konsekuensi apapun yang diberikan.\n   \
(%s)" % (NAMA, KELAS, NPM, NAMA)

print(PERNYATAAN_INTEGRITAS)
# Out:
# Saya, Riris Melissa Winona Togatorop dari kelas E dengan NPM 1906398906, menyatakan bahwa seluruh jawaban pada pekerjaan ini murni saya kerjakan sendiri.
# Saya tidak mencontek jawaban, memberikan jawaban, maupun menyalin dari sumber manapun.
#
# Jika saya melanggar pernyataan tersebut, saya siap menerima konsekuensi apapun yang diberikan.
#    (Riris Melissa Winona Togatorop)

# %% [markdown]
# # Exploratory Data Analysis
#
# *Exploratory Data Analysis* (EDA) merupakan suatu proses menganalisis dataset untuk melihat karakteristik utama dari data. EDA adalah pemrosesan dasar yang dapat mempengaruhi keputusan-keputusan seorang data scientist dalam memproses data di tahap selanjutnya. Proses ini sering melibatkan dua hal, di antaranya *descriptive statistics* dan data *visualization*.

# %% [markdown]
# ## Deskripsi Dataset Fuel Consumption
#
# Tabel di bawah menunjukkan data rate penggunaan bahan bakar dan perkiraan emisi Karbon Dioksida pada mobil ringan di Kanada pada tahun 2022.
# * `Make`: Nama brand mobil
# * `Model`: Nama model mobil
# * `Vehicle Class`: Nama kelas atau tipe kendaraan
# * `Engine Size(L)`: Ukuran mesin
# * `Cylinders`: Jumlah *cylinder* yang ada pada mesin
# * `Transmission`: Jenis transmisi kendaraan
# * `Fuel Type`: Tipe bahan bakar yang digunakan
# * `Fuel Consumption (City (L/100 km)`: Rata-rata konsumsi bahan bakar dalam perkotaan
# * `Fuel Consumption(Hwy (L/100 km))`: Rata-rata konsumsi bahan bakar dalam jalan raya
# * `Fuel Consumption(Comb (L/100 km))`: Rata-rata konsumsi bahan bakar dalam perkotaan dan jalan raya
# * `CO2 Emissions(g/km)`: Emisi gas buang karbon dioksida (dalam gram per kilometer) untuk gabungan mengemudi di kota dan jalan raya
# * `CO2 Rating`: Emisi knalpot karbon dioksida dinilai pada skala dari 1 (terburuk) hingga 10 (terbaik)
# * `Smog Rating`: Emisi knalpot polutan pembentuk asap yang dinilai pada skala dari 1 (terburuk) hingga 10 (terbaik)
# * `Region` : Region brand mobil berasal

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as scp
import plotly.express as px
import matplotlib.pyplot as plt
from numpy.polynomial.polynomial import polyfit

# %%
df = pd.read_csv('FuelConsumptionCO2.csv')

# %%
total_rows, total_attributes = df.shape
print('Jumlah data:', total_rows)
print("Jumlah atribut:", total_attributes)

df.head()
# Out:
# Jumlah data: 946
# Jumlah atribut: 14
#     Make              Model Vehicle Class  Engine Size(L)  Cylinders  \
# 0  Acura                ILX       Compact             2.4          4
# 1  Acura         MDX SH-AWD    SUV: Small             3.5          6
# 2  Acura         RDX SH-AWD    SUV: Small             2.0          4
# 3  Acura  RDX SH-AWD A-SPEC    SUV: Small             2.0          4
# 4  Acura         TLX SH-AWD       Compact             2.0          4
#
#   Transmission Fuel Type  Fuel Consumption (City (L/100 km)  \
# 0          AM8         Z                                9.9
# 1         AS10         Z                               12.6
# 2         AS10         Z                               11.0
# 3         AS10         Z                               11.3
# 4         AS10         Z                               11.2
#
#    Fuel Consumption(Hwy (L/100 km))  Fuel Consumption(Comb (L/100 km))  \
# 0                               7.0                                8.6
# ...

# %%
# Melihat kolom-kolom pada dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 946 entries, 0 to 945
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Make                               946 non-null    object
#  1   Model                              946 non-null    object
#  2   Vehicle Class                      946 non-null    object
#  3   Engine Size(L)                     946 non-null    float64
#  4   Cylinders                          946 non-null    int64
#  5   Transmission                       946 non-null    object
#  6   Fuel Type                          946 non-null    object
#  7   Fuel Consumption (City (L/100 km)  946 non-null    float64
#  8   Fuel Consumption(Hwy (L/100 km))   946 non-null    float64
#  9   Fuel Consumption(Comb (L/100 km))  946 non-null    float64
#  10  CO2 Emissions(g/km)                946 non-null    int64
# ...

# %%
df.describe()
# Out:
#        Engine Size(L)   Cylinders  Fuel Consumption (City (L/100 km)  \
# count      946.000000  946.000000                         946.000000
# mean         3.198732    5.668076                          12.506448
# std          1.374814    1.932670                           3.452043
# min          1.200000    3.000000                           4.000000
# 25%          2.000000    4.000000                          10.200000
# 50%          3.000000    6.000000                          12.200000
# 75%          3.800000    6.000000                          14.700000
# max          8.000000   16.000000                          30.300000
#
#        Fuel Consumption(Hwy (L/100 km))  Fuel Consumption(Comb (L/100 km))  \
# count                        946.000000                         946.000000
# mean                           9.363319                          11.092072
# std                            2.285125                           2.876276
# ...

# %%
df.describe(include=['object'])
# Out:
#         Make                           Model Vehicle Class Transmission  \
# count    946                             946           946          946
# unique    39                             715            14           23
# top     Ford  Silverado 4WD Mud Terrain Tire    SUV: Small          AS8
# freq      89                               5           197          212
#
#        Fuel Type  Region
# count        946     946
# unique         4       3
# top            Z  Europe
# freq         458     352

# %% [markdown]
# # Descriptive Statistics
# Ada banyak jenis measures yang dapat diterapkan untuk *descriptive statistics*.
#
# Mengingat materi dari StatProb, ada
# 1. *Central tendency* (mean, median, mode)
# 2. *Dispersion* atau *variability* (variance, standard deviation)
# 3. Minimum, maximum
# 4. Range
# 5. Quantile
# 6. Percentile
#
# **Central tendency sering dipakai untuk melihat distribusi data.**
# Pada biasanya, `mean` lebih cocok untuk distribusi normal (yang terlihat simetris di tengah), sementara `median` lebih baik untuk distribusi bersifat *skewed* (berat sebelah). Tentunya, ini tidak berlaku untuk data kategorik yang hanya bisa menggunakan `mode`.
#
# Terkadang central tendency saja tidak cukup untuk melihat distribusi data. Central tendency tidak bisa menggambarkan seberapa besar data tersebar. **Measure of dispersion merupakan ukuran yang biasa digunakan untuk melihat keragaman data atau seberapa besar data tersebar.** Terdapat beberapa ukuran untuk menentukan dispersi data pengamatan, seperti jangkauan/rentang (`range`) dan simpangan baku (`standard deviation`).
#
# Secara umum, berikut adalah contoh penggunaan descriptive statistics (1), (2), (3) dari atribut `Engine Size(L)`:

# %%
engine_arr = df['Engine Size(L)']

stats = [
    ['Mean', np.mean(engine_arr)],
    ['Median', np.median(engine_arr)],
    ['Mode', scp.mode(engine_arr)[0][0]],
    ['Standard Deviation', np.std(engine_arr)],
    ['Variance', np.var(engine_arr)],
    ['Minimum', np.min(engine_arr)],
    ['Maximum', np.max(engine_arr)],
]

pd.DataFrame(stats, columns=['Measure', 'Value'])
# Out:
#               Measure     Value
# 0                Mean  3.198732
# 1              Median  3.000000
# 2                Mode  2.000000
# 3  Standard Deviation  1.374088
# 4            Variance  1.888117
# 5             Minimum  1.200000
# 6             Maximum  8.000000

# %% [markdown]
# Pada hasil diatas, bisa kita lihat bahwa `mean` > `median` > `mode`. Data tersebar sebesar 1.37 dari nilai `mean`. dengan nilai maksimum 8 dan minimum 1.2. Kemungkinan data cenderung padat di nilai yang rendah atau padat ke kiri.

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(engine_arr, shade=True)
plt.vlines(x=np.mean(engine_arr), ymin=0, ymax=1, color='blue', linestyle='--')
plt.vlines(x=np.median(engine_arr), ymin=0, ymax=1, color='brown', linestyle='--')
plt.vlines(x=scp.mode(engine_arr)[0][0], ymin=0, ymax=1, color='red', linestyle='--')
plt.legend(['Engine Size', 'Mean', 'Median', 'Mode'], fontsize=12)
plt.show()
# Out:
# /var/folders/5w/17bfb9717w7_y1j1p18z6qzm0000gn/T/ipykernel_14354/2660082372.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(engine_arr, shade=True)

# %% [markdown]
# Bisa dilihat bahwa distribusi bersifat `right skewed` karena lebih berat di kiri dan ekornya panjang di kanan. Berdasarkan visualisasi, `median`, `mean`, `modus` tidak selalu sama. Pada kasus ini, median dapat menjadi pengukuran yang tepat untuk menggambarkan central tendency dari data

# %% [markdown]
# Untuk membandingkan distribusi data A ke data B, kita dapat menggunakan overlapping KDE plot.
#
# Misal kita ingin membandingkan distribusi Engine Size pada Honda dan Hyundai.

# %%
# KDE Plot
honda = df[df['Make'] == 'Honda']
hyundai = df[df['Make'] == 'Hyundai']
plt.figure(figsize=(7,5))
sns.kdeplot(honda['Engine Size(L)'], shade=True)
sns.kdeplot(hyundai['Engine Size(L)'], shade=True)
plt.legend(['Honda','Hyundai'], fontsize=12)
plt.vlines(x=honda['Engine Size(L)'].mean(), ymin=0, ymax=0.9, color='blue', linestyle='--')
plt.vlines(x=hyundai['Engine Size(L)'].mean(), ymin=0, ymax=0.9, color='brown', linestyle='--')
plt.show()
# Out:
# /var/folders/5w/17bfb9717w7_y1j1p18z6qzm0000gn/T/ipykernel_14354/2327207900.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(honda['Engine Size(L)'], shade=True)
# /var/folders/5w/17bfb9717w7_y1j1p18z6qzm0000gn/T/ipykernel_14354/2327207900.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(hyundai['Engine Size(L)'], shade=True)

# %% [markdown]
# # Correlation
#
# Korelasi merupakan pengukuran dependensi antar atribut dalam data. Korelasi sering digunakan untuk mengukur apakah suatu atribut memiliki hubungan yang kuat secara linier atau tidak.
#
# Terdapat beberapa jenis korelasi yang dapat digunakan pada jenis data yang berbeda. ***Pearson correlation*** umum digunakan untuk mengukur korelasi pada atribut numerik.

# %%
df.corr(method='pearson')
# Out:
#                                    Engine Size(L)  Cylinders  \
# Engine Size(L)                           1.000000   0.920698
# Cylinders                                0.920698   1.000000
# Fuel Consumption (City (L/100 km)        0.834925   0.845688
# Fuel Consumption(Hwy (L/100 km))         0.749374   0.737652
# Fuel Consumption(Comb (L/100 km))        0.818694   0.821718
# CO2 Emissions(g/km)                      0.824188   0.833241
# CO2 Rating                              -0.766333  -0.762157
# Smog Rating                             -0.448239  -0.502149
#
#                                    Fuel Consumption (City (L/100 km)  \
# Engine Size(L)                                              0.834925
# Cylinders                                                   0.845688
# Fuel Consumption (City (L/100 km)                           1.000000
# Fuel Consumption(Hwy (L/100 km))                            0.922850
# ...

# %% [markdown]
# Dari korelasi pearson diatas, kita bisa menentukan pasangan atribut apa saja yang memiliki relasi yang tinggi (warna hijau gelap). Untuk membuktikan, dibawah terdapat 2 scatterplot yang menunjukkan hubungan linear dengan `Cylinders`, yakni
# * `Engine Size(L)`: 0.92
# * `CO2 Rating`: -0.77

# %%
w = df["Cylinders"]
z = df["Engine Size(L)"]
df.plot.scatter(x="Cylinders", y="Engine Size(L)", figsize=(6,4))
b, m = polyfit(w, z, 1)
plt.plot(w, b + m * w, '-')
plt.show()

# %%
w = df["Cylinders"]
z = df["CO2 Rating"]
df.plot.scatter(x="Cylinders", y="CO2 Rating", figsize=(6,4))
b, m = polyfit(w, z, 1)
plt.plot(w, b + m * w, '-')
plt.show()

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(25,20))
plt.yticks(size=20)

#to increase x ticks 
plt.xticks(size=20)
# Fungsi yang membuat plot untuk melihat distribusi frekuensi untuk satu kolom/atribut
sns.countplot(y='Make', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Make'>

# %% [markdown]
# Bisa kita lihat pada countplot di atas, Ford adalah brand mobil yang paling banyak digunakan di Kanada

# %%
plt.figure(figsize=(25,20))
plt.yticks(size=20)

#to increase x ticks 
plt.xticks(size=20)
sns.countplot(y='Transmission', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Transmission'>

# %% [markdown]
# Dari countplot, transmisi AS8 paling banyak digunakan, dan A7 paling sedikit

# %%
# Menampilkan boxplot Make terhadap Engine Size(L)
plt.figure(figsize=(30,10))
plt.xticks(size=20, rotation=90)
plt.yticks(size=20)
sns.boxplot(data=df, x='Make', y='Engine Size(L)')
# Out:
# <AxesSubplot:xlabel='Make', ylabel='Engine Size(L)'>

# %% [markdown]
# # Latihan Soal

# %% [markdown]
# ### **SOAL 1: Descriptive Statistics**
#
# (a) Tampilkan descriptive statistics dari atribut `CO2 Emissions(g/km)`! (hint: tambahkan range, Q1, Q2, Q3)

# %%
# Jawab
co2emissiongkm = df['CO2 Emissions(g/km)']

desc_stat = [
    ['Mean', np.mean(co2emissiongkm)],
    ['Median', np.median(co2emissiongkm)],
    ['Standard Deviation', np.std(co2emissiongkm)],
    ['Variance', np.var(co2emissiongkm)],
    ['Minimum', np.min(co2emissiongkm)],
    ['Maximum', np.max(co2emissiongkm)],
    ['Range', np.max(co2emissiongkm)-np.min(co2emissiongkm)],
    ['Q1', np.quantile(co2emissiongkm,0.25)],
    ['Q2', np.quantile(co2emissiongkm,0.5)],
    ['Q3', np.quantile(co2emissiongkm,0.75)],
]
pd.DataFrame(desc_stat, columns=['Measure', 'Value'])
# Out:
#               Measure        Value
# 0                Mean   259.172304
# 1              Median   257.000000
# 2  Standard Deviation    64.409079
# 3            Variance  4148.529508
# 4             Minimum    94.000000
# 5             Maximum   608.000000
# 6               Range   514.000000
# 7                  Q1   213.250000
# 8                  Q2   257.000000
# 9                  Q3   300.750000

# %% [markdown]
# (b) Apa central tendency paling cocok untuk atribut `CO2 Emissions(g/km)`? Berikan alasan!

# %%
# Jawab
plt.figure(figsize=(10,5))
sns.kdeplot(co2emissiongkm, shade=True)
plt.vlines(x=np.mean(co2emissiongkm), ymin=0, ymax=0.006, color='blue', linestyle='--')
plt.vlines(x=np.median(co2emissiongkm), ymin=0, ymax=0.006, color='yellow', linestyle='--')
plt.vlines(x=scp.mode(co2emissiongkm)[0][0], ymin=0, ymax=0.006, color='red', linestyle='--')
plt.legend(['Engine Size', 'Mean', 'Median', 'Mode'], fontsize=12)
plt.show()
# Out:
# /var/folders/5w/17bfb9717w7_y1j1p18z6qzm0000gn/T/ipykernel_14354/2872422568.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(co2emissiongkm, shade=True)

# %% [markdown]
# Pada plot di atas, dapat dilihat bahwa distribusi tersebut bersifat `right skewed` karena lebih condong ke kanan dan ekornya lebih panjang di kanan. Dari hasil visualisasi tersebut, data juga tidak terdistribusi secara simetris sehingga Central Tendency yang tepat untuk atribut tersebut adalah `median`.

# %% [markdown]
# (c) Buatlah heatmap dari korelasi pearson pada dataset `FuelConsumptionCO2.csv`!

# %%
# Jawab

import seaborn as sns
import matplotlib.pyplot as pyplot

plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### **SOAL 2: Data Visualization**
#
# Untuk setiap sub-soal, pilih salah satu dari visualisasi berikut:
# * Pie chart
# * Bar chart
# * Scatter plot
# * Box plot
# * Histogram
# * KDE Plot
#
# Beberapa kasus terkadang memiliki lebih dari satu "jawaban yang tepat", karena ada banyak cara untuk visualisasi data. Pilihlah yang menurut Anda paling cocok berdasarkan kasus yang diberikan.
#
# **Secara eksplisit, tulis chart apa yang Anda pilih dan alasannya.**
#
# (a) Buatlah visualisasi untuk melihat jumlah rata-rata ukuran mesin yang dimiliki tiap brand mobil. Apakah mobil Dodge memiliki ukuran mesin terbesar?

# %%
# Jawab
plt.figure(figsize=(10, 3))

# Mengambil data Make dan juga Engine Size
data = df[["Make", "Engine Size(L)"]]

# Mengelompokkan data berdasarkan Brandnya
groupedby_make = data.groupby("Make")

# Merata-ratakan Ukuran Mesin Tiap Brand
mean_data = groupedby_make.mean()
mean_data = mean_data.reset_index()

# Mengurutkan Brand Berdasarkan Rata-Rata Ukuran Mesin dari yang Terkecil
mean_data.sort_values(by="Engine Size(L)", inplace=True)

# membuat bar chart dengan bar sebanyak baris data
x_coords = np.arange(len(mean_data))
plt.bar(x_coords, mean_data["Engine Size(L)"], tick_label=mean_data["Make"])

# menghias frame
plt.xticks(rotation=90)
plt.xlabel("Brands")
plt.ylabel("Engine Size(L)")
plt.title("Rata-Rata Ukuran Mesin yang Dimiliki Tiap Brand Mobil")
plt.show()

# %% [markdown]
# Visualisasi data yang saya gunakan adalah dengan menggunakan Bar Chart untuk menyajikan perbandingan data pada satu atau beberapa seri data. Pertama, data dikelompokkan terlebih dahulu berdasarkan brandnya, yang kemudian dirata-ratakan. Setelah itu data diurutkan dan divisualisasikan menggunakan Bar Chart, hal ini memudahkan untuk melihat nilai rata-rata yang sudah diurutkan dari yang paling kecil hingga besar dengan rapih. Dodge bukanlah brand mobil yang nilai rata-rata ukuran mesinnya paling besar. Adapun rata-rata ukuran mesin terbesar adalah Bugatti.

# %% [markdown]
# ***

# %% [markdown]
# (b) Buatlah visualisasi dari persentase mobil yang memiliki smog rating dengan nilai >= 7. Berapakah persentase dari mobil Eropa yang memiliki smog rating yang bernilai >= 7?

# %%
# Jawab

# Membuat dataframe baru berdasarkan Region
data = df[["Region", "Smog Rating"]]

# Menyaring data dengan Smog Rating yang bernilai >= 7
data = data[data["Smog Rating"] >= 7]

# Mengelompokkan data berdasarkan region dan menghitung jumlahnya
data = data.groupby("Region").count()
data = data.reset_index()
data.set_index("Region", inplace=True)

fig = data.plot.pie(y="Smog Rating", 
                    legend=False,
                    title="Persentase Mobil yang Memiliki Smog Rating dengan Nilai >= 7",
                    explode = (0, 0, 0.1),
                    shadow=True,
                    autopct='%1.2f%%')

# %% [markdown]
# Visualisasi data yang saya gunakan adalah dengan Pie Chart untuk dapat melihat bagian-bagian dari totalnya dan juga agar dapat melihat persentasenya. Pertama, data disaring berdasarkan Smog Rating yang bernilai >= 7, dan kemudian dikelompokkan berdasarkan Regionnya dan menjumlahkannya. Setelah itu data dibuat ke dalam Pie Chart untuk melihat persentasenya. Bagian Pie Chart yang di explode (terpisah) merupakan negara Europe, persentasenya adalah 30.41%.

# %% [markdown]
# ***

# %% [markdown]
# (c) Buatlah visualisasi untuk melihat apakah ada outliers di atribut `Engine Size(L)` untuk setiap transmisi. Berikan satu contoh transmisi yang terlihat memiliki outlier.

# %%
# Jawab
plt.figure(figsize=(30,10))
plt.xticks(size=20, rotation=90)
plt.yticks(size=20)
sns.boxplot(data=df, x='Transmission', y='Engine Size(L)')
# Out:
# <AxesSubplot:xlabel='Transmission', ylabel='Engine Size(L)'>

# %% [markdown]
# Visualisasi data yang saya gunakan adalah dengan Box Plot untuk dapat melihat melihat distribusi datanya secara menyeluruh. Dari boxplot, kita dapat langsung melihat nilai medium, quartil teratas, quartil terendah, nilai maksimum, nilai minimum, dan juga outliernya. Outlier pada boxplot berupa titik-titik yang berada di atas ataupun dibawah nilai maximum (garis pada setiap ujungnya). Ada pun salah satu contoh transimis yang terlihat memiliki outlier adalah AM8 yang memiliki outlier dengan Engine Size berukuran 6.

# %% [markdown]
# ***

# %% [markdown]
# (d) Buatlah visualisasi untuk melihat pola atau pattern antara Engine Size(L) dan Fuel Consumption(Comb (L/100 km)). **Menurut Anda, apa hubungan yang dimiliki antara Engine Size dan Fuel Consumption? Jelaskan!**

# %%
# Jawab
plt.figure(figsize=(15, 10))

engine_size = df["Engine Size(L)"]
fuel_consumption = df["Fuel Consumption(Comb (L/100 km))"]

plt.scatter(engine_size, fuel_consumption)
plt.title("Scatterplot Engine Size VS Fuel Consumption")
plt.xlabel("Engine Size(L)")
plt.ylabel("Fuel Consumption(Comb (L/100 km))")
plt.grid()
plt.show()

# %% [markdown]
# Visualisasi data yang saya gunakan adalah dengan Scatter Plot untuk melihat hubungan/korelasi dari dua variabel. Berdasarkan scatterplot di atas, korelasi antar variabel Engine Size dan Fuel Consumption bernilai positif yang artinya berbanding lurus. Artinya, pada di saat salah satu variabel naik, maka variabel yang lain juga naik. Dengan begitu, semakin besar Engine Size, semakin besar pula Fuel Consumptionnya. Berdasarkan persebaran data itu pula, kita dapat melihat bahwa korelasinya cukup kuat karena persebarannya cukup rapat.

# %% [markdown]
# ***

# %% [markdown]
# (e) Visualisasikan distribusi data CO2 Emissions pada BMW dan Mercedes-Benz. Berikan analisis Anda!

# %%
# Jawab

bmw = df[df['Make'] == 'BMW']
mercedes = df[df['Make'] == 'Mercedes-Benz']
plt.figure(figsize=(15,5))
sns.kdeplot(bmw['CO2 Emissions(g/km)'], shade=True)
sns.kdeplot(mercedes['CO2 Emissions(g/km)'], shade=True)
plt.vlines(x=bmw['CO2 Emissions(g/km)'].mean(), ymin=0, ymax=0.01, color='blue', linestyle='-')
plt.vlines(x=mercedes['CO2 Emissions(g/km)'].mean(), ymin=0, ymax=0.01, color='blue', linestyle='--')
plt.vlines(x=bmw['CO2 Emissions(g/km)'].median(), ymin=0, ymax=0.01, color='red', linestyle='-')
plt.vlines(x=mercedes['CO2 Emissions(g/km)'].median(), ymin=0, ymax=0.01, color='red', linestyle='--')
plt.vlines(x=bmw['CO2 Emissions(g/km)'].mode(), ymin=0, ymax=0.01, color='green', linestyle='-')
plt.vlines(x=mercedes['CO2 Emissions(g/km)'].mode(), ymin=0, ymax=0.01, color='green', linestyle='--')
plt.legend(['BMW','Mercedes-Benz','Mean BMW', 'Mean Mercedes','Median BMW', 'Median Mercedes','Mode BMW', 'Mode Mercedes'], fontsize=12)
plt.show()
# Out:
# /var/folders/5w/17bfb9717w7_y1j1p18z6qzm0000gn/T/ipykernel_14354/140201678.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(bmw['CO2 Emissions(g/km)'], shade=True)
# /var/folders/5w/17bfb9717w7_y1j1p18z6qzm0000gn/T/ipykernel_14354/140201678.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(mercedes['CO2 Emissions(g/km)'], shade=True)

# %% [markdown]
# Visualisasi data yang saya gunakan adalah dengan menggunakan KDE chart.
# Berdasarkan chart tersebut, kita dapat melihat bahwa modus dari Brand BMW lebih condong ke kanan, yang membuat distribusi bersifat right skewed, sedangkan modus dari Brand BMW lebih condong ke kiri yang membuat distribusinya bersifat left skewed.
# Kedua distribusi tersebut juga berbeda, dapat kita lihat bahwa brand BMW memiliki 2 titik puncak sedangkan Mercedes hanya 1 saja.

# %% [markdown]
# ***

# %% [markdown]
# (f) Buatlah visualisasi untuk mengetahui brand mobil Asia mana yang memiliki rata rata `Fuel Consumption(Comb (L/100 km))` yang paling rendah (paling irit). Apa yang membuat brand mobil tersebut irit? `hint: Gunakan Descriptive Statistics`

# %%
# Jawab
plt.figure(figsize=(10, 3))

# mengambil brand mobil Asia
asia_df = df.loc[(df['Region'] ==  'Asia')]
data1 = asia_df[["Make", "Fuel Consumption(Comb (L/100 km))"]]

# Mengelompokkan data berdasarkan Brandnya
groupby_make = data1.groupby("Make")

# Merata-ratakan Fuel Consumption Tiap Brand
mean_fuelcon = groupby_make.mean()
mean_fuelcon = mean_fuelcon.reset_index()

# Mengurutkan Brand Berdasarkan Rata-Rata Fuel Consumption dari yang Terkecil
mean_fuelcon.sort_values(by="Fuel Consumption(Comb (L/100 km))", inplace=True)

# membuat bar chart dengan bar sebanyak baris data
x_coords = np.arange(len(mean_fuelcon))
plt.bar(x_coords, mean_fuelcon["Fuel Consumption(Comb (L/100 km))"], tick_label=mean_fuelcon["Make"])

# menghias frame
plt.xticks(rotation=90)
plt.xlabel("Brands")
plt.ylabel("Average Fuel Consumption(Comb (L/100 km)")
plt.title("Rata-Rata Fuel Consumption(Comb (L/100 km) yang Dimiliki Tiap Brand Mobil Asia")
plt.show()

# %% [markdown]
# Visualisasi data yang saya gunakan adalah dengan menggunakan Bar Chart untuk menyajikan perbandingan data pada satu atau beberapa seri data. Pertama, data disaring hanya dari Region Asia saja, kemudian dikelompokkan berdasarkan brandnya, yang kemudian Fuel Compsumptionnya dirata-ratakan. Setelah itu data diurutkan dan divisualisasikan menggunakan Bar Chart, hal ini memudahkan untuk melihat nilai rata-rata yang sudah diurutkan dari yang paling kecil hingga besar dengan rapih. Hyundai adalah Brand Mobil Asia dengan rata-rata Fuel Consumption (Comb (L/100 km) yang paling rendah (paling irit).

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15, 10))

engine_size = df["Engine Size(L)"]
fuel_consumption = df["Fuel Consumption(Comb (L/100 km))"]

plt.scatter(fuel_consumption,engine_size)
plt.title("Scatterplot Engine Size VS Fuel Consumption")
plt.ylabel("Engine Size(L)")
plt.xlabel("Fuel Consumption(Comb (L/100 km))")
plt.grid()
plt.show()

# %% [markdown]
# Biasanya, CC kendaraan menentukan boros atau iritnya penggunaan bensin. Dari Heat Map dan Scatterplot di atas, kita juga dapat melihat bahwa korelasi antara Engine Size dengan Fuel Consumption bernilai +0.83, yang artinya korelasinya berbanding lurus dan kuat. Semakin besar Engine Size, semakin besar pula Fuel Consumptionnya.

# %%
plt.figure(figsize=(10, 3))

data2= asia_df[["Make", "Engine Size(L)"]]

# Mengelompokkan data berdasarkan Brandnya
groupby_make = data2.groupby("Make")

# Merata-ratakan Engine Size Tiap Brand
mean_enginesize = groupby_make.mean()
mean_enginesize = mean_enginesize.reset_index()

# Mengurutkan Brand Berdasarkan Rata-Rata Engine Size dari yang Terkecil
mean_enginesize.sort_values(by="Engine Size(L)", inplace=True)

# membuat bar chart dengan bar sebanyak baris data
x_coords = np.arange(len(mean_enginesize))
plt.bar(x_coords, mean_enginesize["Engine Size(L)"], tick_label=mean_enginesize["Make"])

# menghias frame
plt.xticks(rotation=90)
plt.xlabel("Brands")
plt.ylabel("Average Engine Size")
plt.title("Rata-Rata Engine Size yang Dimiliki Tiap Brand Mobil Asia")
plt.show()

# %% [markdown]
# Kemudian, saya membuat Bar Chart lagi menggunakan rata-rata dari Engine Size dari tiap brand mobil di Asia yang kemudian diurutkan dari yang paling kecil. Dari sini kita juga dapat melihat bahwa rata-rata Engine Size dari brand Hyundai juga paling kecil. Dari sini kita dapat melihat bahwa Engine Size mempengaruhi keiritan mobil.
